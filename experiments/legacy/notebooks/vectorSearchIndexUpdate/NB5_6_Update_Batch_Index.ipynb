# %% [markdown]
# # Objective
#
# Undeploy & Delete unused Vertex AI Vector Search Indexes.

# %% [markdown]
# # Install

# %%
# !pip install google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.38.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.12.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.11.0)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.17.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.60.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.23.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2023.11.17)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.1)

# %% [markdown]
# ---
#
# #### ⚠️ Do not forget to click the "RESTART RUNTIME" button above.
#
# ---

# %% [markdown]
# # Authenticate

# %%
import sys

if 'google.colab' in sys.modules:
    from google.colab import auth as google_auth
    google_auth.authenticate_user()

# %%
PROJECT_ID = 'solutions-2023-mar-107' # @param {type:"string"}
REGION = 'us-central1' # @param {type:"string"}
BUCKET_URI = "gs://vector_search_regional/flipkart_batch_update" # @param {type:"string"} # WHERE EMBEDDINGS ARE STORED
ENDPOINT = "{}-aiplatform.googleapis.com".format(REGION)

# %% [markdown]
# List all the deployed index

# %%
# !gcloud ai index-endpoints list \
  --project=$PROJECT_ID \
  --region=$REGION
# Out:
# Using endpoint [https://us-central1-aiplatform.googleapis.com/]
# ---
# createTime: '2023-12-18T08:15:01.086330Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-12-18T08:15:52.664772Z'
#   deploymentGroup: default
#   id: flipkart_multimodal_18K
#   index: projects/411826505131/locations/us-central1/indexes/2594851839597871104
#   indexSyncTime: '2023-12-18T09:11:37.090339Z'
# description: Endpoint on flipkart
# displayName: flipkart_batch
# encryptionSpec: {}
# etag: AMEw9yOXuIk7A9H9NmtcLZIEzOzIHB9Bg0xAO4CH0Jd_GqhfaJR2lsD430wsz6ZflYXO
# name: projects/411826505131/locations/us-central1/indexEndpoints/6297373683249840128
# publicEndpointDomainName: 1154454212.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-12-18T08:15:01.784596Z'
# ---
# createTime: '2023-12-08T10:20:13.996148Z'
# deployedIndexes:
# - createTime: '2023-12-08T10:24:03.327365Z'
#   dedicatedResources:
#     machineSpec:
#       machineType: e2-standard-16
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   deploymentGroup: default
#   displayName: flipkart_streaming_filtering_endpoint
#   id: flipkart_streaming_filteri_1702030773989
#   index: projects/411826505131/locations/us-central1/indexes/6070927064486117376
#   indexSyncTime: '2023-12-18T09:13:21.397738Z'
# displayName: flipkart_streaming_filtering_endpoint
# encryptionSpec: {}
# etag: AMEw9yPSd_cYi9KjB0RG3YlZAxeGEu44U4QoBwfL9Dh7mDoI980sQF1-RWXOvSYd-O-A
# name: projects/411826505131/locations/us-central1/indexEndpoints/1641918305943945216
# publicEndpointDomainName: 216080913.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-12-08T10:20:15.705275Z'
# ---
# createTime: '2023-11-29T16:10:26.463182Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-11-29T16:10:28.060348Z'
#   deploymentGroup: default
#   id: flipkart_batch_filtering
#   index: projects/411826505131/locations/us-central1/indexes/4261605914190020608
#   indexSyncTime: '2023-12-18T09:11:47.165260Z'
# description: Endpoint for flipkart_batch_filtering
# displayName: flipkart_batch_filtering_endpoint
# encryptionSpec: {}
# etag: AMEw9yND__0FG0SWHy0fLSBHc4xeCdA7c4Yl8zYIcA_o35yN4yqo3KNaAMN1aynpXh_y
# name: projects/411826505131/locations/us-central1/indexEndpoints/4149015923505758208
# publicEndpointDomainName: 848885253.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-11-29T16:10:27.322062Z'
# ---
# createTime: '2023-11-29T02:44:55.471217Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-11-29T03:17:18.150044Z'
#   deploymentGroup: default
#   id: flipkart_multimodal_streaming
#   index: projects/411826505131/locations/us-central1/indexes/9179325601046069248
#   indexSyncTime: '2023-12-18T09:10:05.352568Z'
# description: Based on 18k flipkart product listings for which we have both a description
#   and image
# displayName: flipkart_multimodal_streaming_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yPi1n6S4V2O-XVDS3g2HzghYSQEvw4q29Lw2mjb-f3W5867PJ7W_WGGfNWNJ7A=
# name: projects/411826505131/locations/us-central1/indexEndpoints/4967334049547812864
# publicEndpointDomainName: 1193755681.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-11-29T02:44:56.195478Z'
# ---
# createTime: '2023-11-02T08:24:25.517069Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-11-02T08:25:39.758274Z'
#   deploymentGroup: default
#   id: flipkart_muiltimodal_18K
#   index: projects/411826505131/locations/us-central1/indexes/5316644495645736960
#   indexSyncTime: '2023-12-18T09:10:10.853334Z'
# description: Endpoint for Q4 development on Flipkart dataset
# displayName: flipkart_Q3
# encryptionSpec: {}
# etag: AMEw9yM6UluLi-XVee1s1VuUUO0qWctX478P8rqQySNtmA_U8Xaq2I0zUBXPWYynFa8=
# name: projects/411826505131/locations/us-central1/indexEndpoints/5145507709805658112
# publicEndpointDomainName: 421978469.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-11-02T08:24:26.213626Z'
# ---
# createTime: '2023-09-21T17:52:22.937141Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-09-21T18:01:50.610357Z'
#   deploymentGroup: default
#   id: muiltimodal_13K_train
#   index: projects/411826505131/locations/us-central1/indexes/798535712835108864
#   indexSyncTime: '2023-12-18T09:14:41.437784Z'
# description: Endpoint for Q3 development on mercari
# displayName: mercari_Q3
# encryptionSpec: {}
# etag: AMEw9yM7549h18Vqd8_oBVuR1loOIhkWju0j4yBqnz7oGNbaqBidpf_eva5LuNdvjj99
# name: projects/411826505131/locations/us-central1/indexEndpoints/8767655253467201536
# publicEndpointDomainName: 752804901.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-09-21T17:52:23.696366Z'
# ---
# createTime: '2023-09-01T17:23:51.012426Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-09-01T17:25:32.282432Z'
#   deploymentGroup: default
#   id: muiltimodal_13K
#   index: projects/411826505131/locations/us-central1/indexes/8073397223410368512
#   indexSyncTime: '2023-12-18T09:09:45.753096Z'
# description: Endpoint for Q3 development on mercari
# displayName: mercari_Q3
# encryptionSpec: {}
# etag: AMEw9yOuAFlP81Ltud6Hm7-60ufz2oquTJIAqTnZ7h_96MLebluJ0lJNfXWHWu7MirVX
# name: projects/411826505131/locations/us-central1/indexEndpoints/3917700667254243328
# publicEndpointDomainName: 186864686.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-09-01T17:23:51.669414Z'
# ---
# createTime: '2023-07-15T19:01:35.643835Z'
# deployedIndexes:
# - createTime: '2023-07-15T19:02:36.020021Z'
#   dedicatedResources:
#     machineSpec:
#       machineType: e2-standard-2
#     maxReplicaCount: 10
#     minReplicaCount: 2
#   deploymentGroup: default
#   displayName: nfl_langchain_vectors_20230715190235
#   id: nfl_langchain_vectors_20230715190235
#   index: projects/411826505131/locations/us-central1/indexes/5478127569393942528
#   indexSyncTime: '2023-12-18T09:13:49.253800Z'
# displayName: nfl-langchain-vectors-endpoint
# encryptionSpec: {}
# etag: AMEw9yMAMDn7N6lZC6NCHrTyGag7-rDfxfKTRGthue8MMkCGsZIJzHC7s7uE0bKHx4Mc
# name: projects/411826505131/locations/us-central1/indexEndpoints/6291871727064449024
# publicEndpointDomainName: 681729851.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-07-15T19:01:36.445773Z'
# ---
# createTime: '2023-06-28T01:15:26.171908Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-28T01:18:20.355032Z'
#   deploymentGroup: default
#   displayName: nflpublic
#   id: nflpublic
#   index: projects/411826505131/locations/us-central1/indexes/542639774633033728
#   indexSyncTime: '2023-12-18T09:13:19.253777Z'
# displayName: nflpublic
# encryptionSpec: {}
# etag: AMEw9yOuTMFn2H8nhs6kkKyIVisii9FKFDyGKtCfuzrGB9Gii0RQoPz8jRXqoHq4Eooj
# name: projects/411826505131/locations/us-central1/indexEndpoints/6608988472701091840
# publicEndpointDomainName: 2006714038.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-28T01:15:27.280106Z'
# ---
# createTime: '2023-06-27T22:08:39.397149Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-27T22:21:28.373400Z'
#   deploymentGroup: default
#   displayName: mecari_stream
#   id: mecari_stream
#   index: projects/411826505131/locations/us-central1/indexes/3876429398794043392
#   indexSyncTime: '2023-12-18T09:09:50.850993Z'
# displayName: index_endpoint_for_mecari_stream
# encryptionSpec: {}
# etag: AMEw9yPvhp8XO-NXRG3-XEk6xzv7bqueNbhIaqf0khiUm_gAyjMU1cbrQHAECnpJRxE=
# name: projects/411826505131/locations/us-central1/indexEndpoints/4652174434608611328
# publicEndpointDomainName: 1297530219.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-27T22:08:40.222549Z'
# ---
# createTime: '2023-06-21T00:25:27.415656Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-21T00:26:15.712235Z'
#   deploymentGroup: default
#   displayName: mecari1mm
#   id: mecari1mm
#   index: projects/411826505131/locations/us-central1/indexes/3625916669521559552
#   indexSyncTime: '2023-12-18T09:12:07.469050Z'
# displayName: mecari1mm
# encryptionSpec: {}
# etag: AMEw9yOylDYz9LL8cBg7yqo-ZYtcQJBN2-WtlpbhFNcJNacor34GBYe--_o-YF2gSLI=
# name: projects/411826505131/locations/us-central1/indexEndpoints/5135748444597518336
# publicEndpointDomainName: 1122704120.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-21T00:25:28.167187Z'
# ---
# createTime: '2023-06-20T21:49:40.576504Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-20T21:51:00.433795Z'
#   deploymentGroup: default
#   displayName: mecari2
#   id: mecari2
#   index: projects/411826505131/locations/us-central1/indexes/3743010259833192448
#   indexSyncTime: '2023-12-18T09:11:24.345880Z'
# displayName: mecari2
# encryptionSpec: {}
# etag: AMEw9yOYAAn3OkkQ93IxNG0v3NEy_XzKXkcKubXG3tZiUBbIjs9v0GQ94GrVgjVnLahN
# name: projects/411826505131/locations/us-central1/indexEndpoints/5726845895689895936
# publicEndpointDomainName: 1681326733.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-20T21:49:41.278695Z'
# ---
# createTime: '2023-06-20T19:57:04.598784Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-20T19:58:13.243293Z'
#   deploymentGroup: default
#   displayName: mecari
#   id: mecari
#   index: projects/411826505131/locations/us-central1/indexes/1720894027143839744
#   indexSyncTime: '2023-12-18T09:12:55.950429Z'
# displayName: mecari
# encryptionSpec: {}
# etag: AMEw9yP5HNl-k-M0h7o0xTeuntpk1m4WdoJAXdTe9mNmIcaimzP2s6M3Wn4FaDZ1SgdF
# name: projects/411826505131/locations/us-central1/indexEndpoints/8609149657207013376
# publicEndpointDomainName: 297840358.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-20T19:57:05.467462Z'
# ---
# createTime: '2023-06-20T02:02:38.474125Z'
# deployedIndexes:
# - automaticResources:
#     maxReplicaCount: 2
#     minReplicaCount: 2
#   createTime: '2023-06-20T02:03:41.596884Z'
#   deploymentGroup: default
#   displayName: ecommercex
#   id: ecommercex
#   index: projects/411826505131/locations/us-central1/indexes/6278818325019492352
#   indexSyncTime: '2023-12-18T09:12:42.785480Z'
# displayName: gsecommercex
# etag: AMEw9yNdfzpML3RR_G7Jk94yGTX7Fv55Wg7-NTwVzFpHtADqWrOKhm4MnV1GTZXoVYM=
# name: projects/411826505131/locations/us-central1/indexEndpoints/8471789868572213248
# publicEndpointDomainName: 1223588271.us-central1-411826505131.vdb.vertexai.goog
# updateTime: '2023-06-20T02:02:39.028096Z'

# %%
# !gcloud ai indexes list \
  --project=$PROJECT_ID \
  --region=$REGION
# Out:
# Using endpoint [https://us-central1-aiplatform.googleapis.com/]
# ---
# createTime: '2023-12-18T06:51:22.796157Z'
# deployedIndexes:
# - deployedIndexId: flipkart_multimodal_18K
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/6297373683249840128
# description: Based on ~18K Flipkart product listings with both description and image
# displayName: flipkart_batch
# encryptionSpec: {}
# etag: AMEw9yPw4ORvCK7Tce2FF5m6KjZig3J_NeP0gt5cI59Ysrg3h4NEhJ7AHZkD2E1tJal2
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36394'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/2594851839597871104
# updateTime: '2023-12-18T10:09:10.643435Z'
# ---
# createTime: '2023-12-18T09:03:01.366486Z'
# deployedIndexes:
# - deployedIndexId: flipkart_streaming_with_filters
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/4968248843222122496
# description: Glove 100 ANN index
# displayName: flipkart_streaming_with_filters
# encryptionSpec: {}
# etag: AMEw9yMCreniNcyL9ZurPi4LS3S_XJdbnNnmj5QwStmnBhZGNgtWbgGFCNRCU850r2c=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/924016377843417088
# updateTime: '2023-12-18T10:05:08.198963Z'
# ---
# createTime: '2023-12-18T08:59:26.272606Z'
# deployedIndexes:
# - deployedIndexId: flipkart_streaming
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/356562824794734592
# description: Based on ~18K Flipkart product listings with both description and image
# displayName: flipkart_streaming
# encryptionSpec: {}
# etag: AMEw9yPJYAdLLUWz9nRIV_tS7FVTuf2QVrBcQYXldJHjDC9Pfum_z_SKC85n4xt17LyF
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/3849667285773975552
# updateTime: '2023-12-18T09:49:30.914172Z'
# ---
# createTime: '2023-12-15T09:26:12.652856Z'
# description: Flipkart ANN index
# displayName: flipkart_stream_filter_test
# encryptionSpec: {}
# etag: AMEw9yN28VERYrjRJgJKmLq4sI0v-lL_Y2BL9KITyiXfdcfQHtM-6Yh2JenGr4cp90NT
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/7375563581540007936
# updateTime: '2023-12-15T10:22:46.407377Z'
# ---
# createTime: '2023-12-13T14:25:29.387524Z'
# description: Based on ~18K Flipkart product listings for which we have both a description
#   and image
# displayName: flipkart_multimodal_batch_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yNPUaMXky4gfHO0mQVpVRKYdT7DGg0l_PCt90w1417OejXTGxDXzZPHMQjgnDKQ
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/9026132844971294720
# updateTime: '2023-12-13T15:25:29.655244Z'
# ---
# createTime: '2023-11-29T11:40:40.741945Z'
# deployedIndexes:
# - deployedIndexId: flipkart_streaming_filteri_1702030773989
#   displayName: flipkart_streaming_filtering_endpoint
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/1641918305943945216
# description: flipkart_streaming_index_with_filters
# displayName: flipkart_streaming_index_with_filters
# encryptionSpec: {}
# etag: AMEw9yN5j-iGcSUjGqCQVa-R6ICFPQXHxchOiFOpfkN98LL4GYmtxEs1gdhiWKheboJ2
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/6070927064486117376
# updateTime: '2023-11-29T12:33:15.453085Z'
# ---
# createTime: '2023-11-29T11:35:10.580208Z'
# deployedIndexes:
# - deployedIndexId: flipkart_batch_filtering
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/4149015923505758208
# description: batch_filtering_test
# displayName: flipkart_batch_filtering
# encryptionSpec: {}
# etag: AMEw9yN9JwGlafrvwOKpfptX5uJ5xYVPe01exMh5QIVKPmYqBD2WLPVsrDBYB2W5BqKU
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/4261605914190020608
# updateTime: '2023-11-29T12:23:34.978458Z'
# ---
# createTime: '2023-11-28T20:54:15.832933Z'
# description: Based on 18k flipkart product listings for which we have both a description
#   and image
# displayName: flipkart_multimodal_streaming_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yMeI5MST5-4EF0ghh0l4p9umocfk6j6R_HHWb_vAWZv6nuZqjWnvhNOQjFyydc=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36374'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/9179325601046069248
# updateTime: '2023-11-28T21:41:44.205696Z'
# ---
# createTime: '2023-11-02T07:30:47.260693Z'
# deployedIndexes:
# - deployedIndexId: flipkart_muiltimodal_18K
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/5145507709805658112
# description: Based on ~18K flipkart product listings for which we have both a description
#   and image
# displayName: flipkart_multimodal_batch_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yNVHA7sserX0qQl5XjminpzlmcNZIYZSaqH5IVOsg4Of_HmxfnzIJgT-THF8a4=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '36720'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/5316644495645736960
# updateTime: '2023-11-02T08:21:46.234940Z'
# ---
# createTime: '2023-09-21T16:49:49.156621Z'
# deployedIndexes:
# - deployedIndexId: muiltimodal_13K_train
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/8767655253467201536
# description: Based on ~13K mercari product listings for which we have both a description
#   and image
# displayName: mercari_multimodal_batch_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yP95kXla3rdSoPyAptkTo7tzvieUOE4QjJZHxmJbQA4un9Z0WyM-rMgEvptJ-Op
# indexStats:
#   shardsCount: 1
#   vectorsCount: '26618'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/798535712835108864
# updateTime: '2023-09-21T17:52:19.780044Z'
# ---
# createTime: '2023-09-13T15:50:55.783195Z'
# description: Index for LangChain demo
# displayName: solutions-2023-mar-107-retail-products-index
# encryptionSpec: {}
# etag: AMEw9yNdapbTPyKHscoyWQRQ3XvK1cSOO18sGGFkcFSrq_eIdOgtJLKTfPyVrFx8oe01
# indexStats:
#   shardsCount: 1
#   vectorsCount: '1'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       bruteForceConfig: {}
#     dimensions: 768
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_SMALL
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/5515634110040637440
# updateTime: '2023-09-13T16:48:58.892472Z'
# ---
# createTime: '2023-08-31T21:11:10.168164Z'
# deployedIndexes:
# - deployedIndexId: muiltimodal_13K
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/3917700667254243328
# description: Based on ~13K mercari product listings for which we have both a description
#   and image
# displayName: mercari_multimodal_batch_tree_cosine
# encryptionSpec: {}
# etag: AMEw9yPyqZ82E6ywd6WI8A_iBA1XENL4xWJP-pfYR4Sups3MeTdXlBqggfjKkgMiDP4=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '26900'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1408
#     distanceMeasureType: COSINE_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/8073397223410368512
# updateTime: '2023-08-31T22:12:10.126378Z'
# ---
# createTime: '2023-07-15T16:55:08.717906Z'
# deployedIndexes:
# - deployedIndexId: nfl_langchain_vectors_20230715190235
#   displayName: nfl_langchain_vectors_20230715190235
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/6291871727064449024
# description: Index for LangChain demo
# displayName: nfl-langchain-vectors
# encryptionSpec: {}
# etag: AMEw9yN5bEN7wnSR-83wCsW16dgCxfloK3mhQCmRYi_DfNFq2YsqT3QTdW20v_RIqCaA
# indexStats:
#   shardsCount: 1
#   vectorsCount: '386'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 768
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_SMALL
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/5478127569393942528
# updateTime: '2023-07-18T20:36:39.905425Z'
# ---
# createTime: '2023-06-27T21:05:07.917558Z'
# deployedIndexes:
# - deployedIndexId: nflpublic
#   displayName: nflpublic
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/6608988472701091840
# description: Mecari 1MM Streamed
# displayName: nfl
# encryptionSpec: {}
# etag: AMEw9yNmbSxClfG-1bc6UdNe2zTAhHqXTWf8aSr1VuTVwWOUo20NZPkKeJ4gxwA8m4mc
# indexStats:
#   shardsCount: 1
#   vectorsCount: '5'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 768
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/542639774633033728
# updateTime: '2023-06-27T22:00:07.352609Z'
# ---
# createTime: '2023-06-27T17:41:37.030679Z'
# deployedIndexes:
# - deployedIndexId: mecari_stream
#   displayName: mecari_stream
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/4652174434608611328
# description: Mecari 1MM Streamed
# displayName: mecari_stream
# encryptionSpec: {}
# etag: AMEw9yNVcB9g7bKt0hgYhqJoLx3BfiD8Y9tKvxk6Ji2TDm4ZcJO3YkxQe-pduy3_qIbK
# indexStats:
#   shardsCount: 1
#   vectorsCount: '994192'
# indexUpdateMethod: STREAM_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1024
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/3876429398794043392
# updateTime: '2023-06-27T18:59:44.436537Z'
# ---
# createTime: '2023-06-20T22:00:36.655817Z'
# deployedIndexes:
# - deployedIndexId: mecari1mm
#   displayName: mecari1mm
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/5135748444597518336
# description: mecari1mm
# displayName: mecari
# encryptionSpec: {}
# etag: AMEw9yOfWIDtjOIbFgnFG34ENrbFJ82XONAsMTCD-06joMNdMnHzWkXzIJOrU7T7P5D-
# indexStats:
#   shardsCount: 1
#   vectorsCount: '994192'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 1024
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/3625916669521559552
# updateTime: '2023-06-20T23:23:40.857405Z'
# ---
# createTime: '2023-06-20T20:00:51.516249Z'
# deployedIndexes:
# - deployedIndexId: mecari2
#   displayName: mecari2
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/5726845895689895936
# description: mecari2
# displayName: mecari
# encryptionSpec: {}
# etag: AMEw9yN0e_jCVVRhWYEF9ULfeqlF1et3gkQVrwLjsLXBzUGbSnxyJJmS1SONYNLpdGF0
# indexStats:
#   shardsCount: 1
#   vectorsCount: '13453'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 2048
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/3743010259833192448
# updateTime: '2023-06-20T20:49:16.463229Z'
# ---
# createTime: '2023-06-20T19:14:25.280114Z'
# description: ecommerce_L2_dist
# displayName: ecommerce_L2_dist
# etag: AMEw9yNroE3AaWyLnr6DouVu2qxejkdIdM8rom0ZeEZtDsVgYimjzMfucJQ90aMkjlEn
# indexStats:
#   shardsCount: 1
#   vectorsCount: '424'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 2048
#     distanceMeasureType: SQUARED_L2_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/6147088035918905344
# updateTime: '2023-06-20T20:02:50.840086Z'
# ---
# createTime: '2023-06-20T18:58:22.552717Z'
# deployedIndexes:
# - deployedIndexId: mecari
#   displayName: mecari
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/8609149657207013376
# description: mecari
# displayName: mecari
# encryptionSpec: {}
# etag: AMEw9yOkS81t4YezSQoO-xJ-UFoM5P9yzZWkJD3CjLvjuhfZUTNRLFaGIxbzDDAD45w=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '423'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 2048
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/1720894027143839744
# updateTime: '2023-06-20T19:49:20.222793Z'
# ---
# createTime: '2023-06-20T00:26:35.025086Z'
# deployedIndexes:
# - deployedIndexId: ecommercex
#   displayName: ecommercex
#   indexEndpoint: projects/411826505131/locations/us-central1/indexEndpoints/8471789868572213248
# description: gsecommerce2
# displayName: gsecommerce2
# etag: AMEw9yMe-qHDPslab2B7rwnaZNdMaZm1cOFpgDBLBcTNM3-1iHG3KGZwF0mjVbONMk6x
# indexStats:
#   shardsCount: 1
#   vectorsCount: '423'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 2048
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/6278818325019492352
# updateTime: '2023-06-20T01:22:58.623465Z'
# ---
# createTime: '2023-06-19T19:45:28.872105Z'
# description: gsecommerce
# displayName: gsecommerce
# etag: AMEw9yPouxrWPX_ksVIEBJt1SqxS84bSHQe8Fpzs8hXoA_Cv_ja7t3xxzL09LVnk9E4=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '132'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 7
#     approximateNeighborsCount: 150
#     dimensions: 100
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/675214488663752704
# updateTime: '2023-06-19T20:41:57.017511Z'
# ---
# createTime: '2023-05-12T18:34:02.668695Z'
# description: questions from stackoverflow
# displayName: stack_overflow
# etag: AMEw9yNwvSPXRuojf2mS4fqGxabeRHAsN3rms9xpfen_73fhOI6zggQuMQR9DG8TQSM=
# indexStats:
#   shardsCount: 1
#   vectorsCount: '489'
# indexUpdateMethod: BATCH_UPDATE
# metadata:
#   config:
#     algorithmConfig:
#       treeAhConfig:
#         leafNodeEmbeddingCount: '500'
#         leafNodesToSearchPercent: 80
#     approximateNeighborsCount: 150
#     dimensions: 768
#     distanceMeasureType: DOT_PRODUCT_DISTANCE
#     shardSize: SHARD_SIZE_MEDIUM
# metadataSchemaUri: gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml
# name: projects/411826505131/locations/us-central1/indexes/3613461401802113024
# updateTime: '2023-05-12T19:13:28.182727Z'

# %% [markdown]
# #### Interested fields
#
# id: flipkart_multimodal_18K
#
# index: projects/411826505131/locations/us-central1/indexes/2594851839597871104
#
# displayName: flipkart_batch
#
#
# name: projects/411826505131/locations/us-central1/indexEndpoints/6297373683249840128

# %%
from google.cloud import aiplatform
aiplatform.init(project=PROJECT_ID, location=REGION, staging_bucket=BUCKET_URI)

# %%
DEPLOYED_INDEX_ID = 'flipkart_multimodal_18K' # @param {type:"string"} #endpoind id
endpoint_name = 'projects/411826505131/locations/us-central1/indexEndpoints/6297373683249840128' # @param {type:"string"} #index id

# %%
my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/411826505131/locations/us-central1/indexEndpoints/6297373683249840128')

# %%
INDEX = 'projects/411826505131/locations/us-central1/indexes/2594851839597871104' # @param {type:"string"}
my_index = aiplatform.MatchingEngineIndex(INDEX)

# %% [markdown]
#  Lets Update the embeddings for this index with update_embeddings
#
#         Args:
#             contents_delta_uri (str):
#                 Required. Allows inserting, updating  or deleting the contents of the Matching Engine Index.
#                 The string must be a valid Google Cloud Storage directory path. If this
#                 field is set when calling IndexService.UpdateIndex, then no other
#                 Index field can be  also updated as part of the same call.
#                 The expected structure and format of the files this URI points to is
#                 described at
#                 https://cloud.google.com/vertex-ai/docs/vector-search/setup/format-structure
#             is_complete_overwrite (bool):
#                 Optional. If this field is set together with contentsDeltaUri when calling IndexService.UpdateIndex,
#                 then existing content of the Index will be replaced by the data from the contentsDeltaUri.
#
#         Returns:
#             MatchingEngineIndex - The updated index resource object.

# %%
my_index.update_embeddings(BUCKET_URI)
# Out:
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Updating MatchingEngineIndex index: projects/411826505131/locations/us-central1/indexes/2594851839597871104
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Update MatchingEngineIndex index backing LRO: projects/411826505131/locations/us-central1/indexes/2594851839597871104/operations/1023688687449276416
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:MatchingEngineIndex index Updated. Resource name: projects/411826505131/locations/us-central1/indexes/2594851839597871104
# <google.cloud.aiplatform.matching_engine.matching_engine_index.MatchingEngineIndex object at 0x7cd034433eb0>
# resource name: projects/411826505131/locations/us-central1/indexes/2594851839597871104

# %% [markdown]
# ---
#
# #### Note: The existing index's vectorsCount gets updated!
#
# ---

# %%
# Query
import base64
from google.cloud import aiplatform
from google.protobuf import struct_pb2
from functools import cache
import time
import typing
import logging

# Inspired from https://stackoverflow.com/questions/34269772/type-hints-in-namedtuple.
class EmbeddingResponse(typing.NamedTuple):
  text_embedding: typing.Sequence[float]
  image_embedding: typing.Sequence[float]


class EmbeddingPredictionClient:
  """Wrapper around Prediction Service Client."""
  def __init__(self, project : str,
    location : str = "us-central1",
    api_regional_endpoint: str = "us-central1-aiplatform.googleapis.com"):
    client_options = {"api_endpoint": api_regional_endpoint}
    # Initialize client that will be used to create and send requests.
    # This client only needs to be created once, and can be reused for multiple requests.
    self.client = aiplatform.gapic.PredictionServiceClient(client_options=client_options)
    self.location = location
    self.project = project

  def get_embedding(self, text : str = None, image_path : str = None):
    """image_path can be a local path or a GCS URI."""
    if not text and not image_path:
      raise ValueError('At least one of text or image_bytes must be specified.')

    instance = struct_pb2.Struct()
    if text:
      if len(text) > 1024:
        logging.warning('Text must be less than 1024 characters. Truncating text.')
        text = text[:1024]
      instance.fields['text'].string_value = text

    if image_path:
      image_struct = instance.fields['image'].struct_value
      if image_path.lower().startswith('gs://'):
        image_struct.fields['gcsUri'].string_value = image_path
      else:
        with open(image_path, "rb") as f:
          image_bytes = f.read()
        encoded_content = base64.b64encode(image_bytes).decode("utf-8")
        image_struct.fields['bytesBase64Encoded'].string_value = encoded_content

    instances = [instance]
    endpoint = (f"projects/{self.project}/locations/{self.location}"
      "/publishers/google/models/multimodalembedding@001")
    response = self.client.predict(endpoint=endpoint, instances=instances)

    text_embedding = None
    if text:
      text_emb_value = response.predictions[0]['textEmbedding']
      text_embedding = [v for v in text_emb_value]

    image_embedding = None
    if image_path:
      image_emb_value = response.predictions[0]['imageEmbedding']
      image_embedding = [v for v in image_emb_value]

    return EmbeddingResponse(
      text_embedding=text_embedding,
      image_embedding=image_embedding)

@cache
def get_client(project):
  return EmbeddingPredictionClient(project)


def embed(project,text,image_path=None):
  client = get_client(project)
  start = time.time()
  response = client.get_embedding(text=text, image_path=image_path)
  end = time.time()
  print('Embedding Time: ', end - start)
  return response

# %%
res = embed(PROJECT_ID,
            "Key Features of Vishudh Printed Women's Straight Kurta BLACK, GREY Straight,Specifications of Vishudh Printed Women's Straight Kurta Kurta Details Sleeve Sleeveless Number of Contents in Sales Package Pack of 1 Fabric 100% POLYESTER Type Straight Neck ROUND NECK General Details Pattern Printed Occasion Festive Ideal For Women's In the Box Kurta Additional Details Style Code VNKU004374 BLACK::GREY Fabric Care Gentle Machine Wash in Lukewarm Water, Do Not Bleach",
            'gs://genai-product-catalog/flipkart_20k_oct26/3ecb859759e5311cbab6850e98879522_0.jpg')
# Out:
# Embedding Time:  0.8157088756561279

# %%
NUM_NEIGHBORS = 5
response = my_index_endpoint.find_neighbors(
    deployed_index_id='my_index',
    queries=[res.text_embedding,res.image_embedding],
    num_neighbors=NUM_NEIGHBORS,
)

response
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      71         try:
# ---> 72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1159         )
# -> 1160         return _end_unary_response_blocking(state, call, False, None)
#    1161
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#    1002     else:
# -> 1003         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1004
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.NOT_FOUND
# 	details = "Index 'my_index' is not found."
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Index \'my_index\' is not found.", grpc_status:5, created_time:"2023-12-18T12:12:53.34762378+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# <ipython-input-35-95b0a117c805> in <cell line: 2>()
#       1 NUM_NEIGHBORS = 5
# ----> 2 response = my_index_endpoint.find_neighbors(
#       3     deployed_index_id='my_index',
#       4     queries=[res.text_embedding,res.image_embedding],
#       5     num_neighbors=NUM_NEIGHBORS,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/matching_engine/matching_engine_index_endpoint.py in find_neighbors(self, deployed_index_id, queries, num_neighbors, filter, per_crowding_attribute_neighbor_count, approx_num_neighbors, fraction_leaf_nodes_to_search_override, return_full_datapoint, numeric_filter)
#    1246             find_neighbors_request.queries.append(find_neighbors_query)
#    1247
# -> 1248         response = self._public_match_client.find_neighbors(find_neighbors_request)
#    1249
#    1250         # Wrap the results in MatchNeighbor objects and return
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/match_service/client.py in find_neighbors(self, request, retry, timeout, metadata)
#     519
#     520         # Send the request.
# --> 521         response = rpc(
#     522             request,
#     523             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     111             kwargs["metadata"] = metadata
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#     115
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
# ---> 74             raise exceptions.from_grpc_error(exc) from exc
#      75
#      76     return error_remapped_callable
#
# NotFound: 404 Index 'my_index' is not found.

# %%
# For complete override
# my_index.update_embeddings(BUCKET_URI, is_complete_overwrite=True)

# %% [markdown]
# ## Update [Batch index with filtering]

# %%
PROJECT_ID = 'solutions-2023-mar-107' # @param {type:"string"}
REGION = 'us-central1' # @param {type:"string"}
BUCKET_URI = "gs://vector_search_regional/flipkart_batch_update" # @param {type:"string"} # WHERE EMBEDDINGS ARE STORED
index_to_be_updated = '4261605914190020608' # @param {type:'string'}

# %%
AUTH_TOKEN = !gcloud auth print-access-token
PROJECT_NUMBER = !gcloud projects list --filter="PROJECT_ID:'{PROJECT_ID}'" --format='value(PROJECT_NUMBER)'
PROJECT_NUMBER = PROJECT_NUMBER[0]

print("PROJECT_NUMBER: {}".format(PROJECT_NUMBER))

# !gcloud config set project {PROJECT_ID} --quiet
# !gcloud config set ai_platform/region {REGION} --quiet


INDEX = 'projects/{0}/locations/{1}/indexes/{2}'.format(PROJECT_NUMBER, REGION, index_to_be_updated)
print("INDEX: {}".format(INDEX))
# Out:
# PROJECT_NUMBER: 411826505131
# Updated property [core/project].
# Updated property [ai_platform/region].
# INDEX: projects/411826505131/locations/us-central1/indexes/4261605914190020608

# %%
# vectorsCount: '36374' -> before update

# %%
from google.cloud import aiplatform

def update_batch_index(index_to_be_updated):
  aiplatform.init(project=PROJECT_ID, location=REGION)
  my_index = aiplatform.MatchingEngineIndex(INDEX)
  my_index.update_embeddings(BUCKET_URI, is_complete_overwrite=False)

# %%
# Updating Batch index (created with filters)
update_batch_index(INDEX)
# Out:
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Updating MatchingEngineIndex index: projects/411826505131/locations/us-central1/indexes/4261605914190020608
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Update MatchingEngineIndex index backing LRO: projects/411826505131/locations/us-central1/indexes/4261605914190020608/operations/3852512203391369216
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:MatchingEngineIndex index Updated. Resource name: projects/411826505131/locations/us-central1/indexes/4261605914190020608

# %%
# vectorsCount: '36394' <- After update

# %%
NUM_NEIGHBORS = 5
my_index = aiplatform.MatchingEngineIndex(INDEX)

response = my_index_endpoint.find_neighbors(
    deployed_index_id='2594851839597871104',
    queries=[res.text_embedding,res.image_embedding],
    num_neighbors=NUM_NEIGHBORS,
)

response
